# %% [markdown]
# # Final Test
#
# Score --> 100 :)
#
# ## UDP protocol?
#
# Faster than TCP and does not use handshakes
#
# ---
#
# ## CRUD in HTTP verbs
#
# POST, GET, PUT, DELETE
#
# ---
#
# ## `r = requests.get('http://localhost:3000')` returns?
#
# an Object
#
# ---
#
# ## Port number is an int with what length?
#
# 16 bits
#
# ---
#
# ## Sock_STREAM transmit single...
#
# characters
#
# ---
#
# ## S in REST stands for?
#
# State
#
# ---
#
# ## `socket.timeout` is a...
#
# an exception
#
# ---
#
# ## JSON string int use Radices????
#
# base 10
#
# ---
#
# ## Json deserializaation means?
#
# Processing JSON string into Python data
#
# ---
#
# ## Empty JSON?
#
# `{ }`
#
# ---
#
# ## Keep-alive Connection header?
#
# **servers** mode of connection management
#
# ---
#
# ## `answ = sock.recv(10000)` has the number which saids...
#
# length of the **internal buffer**
#
# ---
#
# ## `r = requests.delete(url)` does what if it doesn't **exists**
#
# `r.status_code` is set to `requests.codes.not_found`
#
# ---
#
# ## Quotes inside JSON strings?
#
# `" \" "`
#
# ---
#
# ## DTD is?
#
# Document describing structure of an XML doc
#
# ---
#
# ## `json.dumps()`
#
# Takes Python data **and** returns a JSON string
#
# ---
#
# ## XML document contains?
#
# exactly **ONE ROOT ELEMENT** and **any (including 0) number of non-root elements**
#
# ---
#
# ## `json.loads()`
#
# Takes a JSON string as an argument **and** returns a JSON object
#
# ---
#
# ## `r = requests.get(uri)` returns what if it is not able to establish a connection with the server
#
# an exception is raised (timeout or connection timeout)
#
# ---
#
# ## Python `True` is what in Json
#
# true
