# %% [markdown]
# # Reviewed Questions for Exam P2
#
# (answered with ChatGPT)
#
# ## Select the true statement about composition.
# B. Composition allows a class to be projected as a container of different classes.
# - Composition involves creating relationships between classes where one contains an object of another class. Composition is a "has a" relationship but it can be used with inheritance.
#
# ---
#
# ```python
# class Sword:
#     var = 'Weapon'
#
#     def __init__(self):
#         self.name = "Excalibur"
# ```
# Excalibur is the value passed to an instance variable
#
# ---
#
# ```python
# class A:
#     def run (self) :
#         print ("A is running")
# class B:
#     def fly (self):
#         print ("B is flying")
# class C:
#     def run (self) :
#         print ("C is running")
#
# for element in Al(), B(), C():
#     element.run ()
# ```
#
# Polymorphism
#
# ---
#
# ```python
# def my_decorator(coating):
#     def levell_wrapper (my_function) :
#         def level2_wrapper (*args):
#             our_function (*args)
#         return level2_wrapper
#     return level1_wrapper
# ```
#
# The function is erroneous because it runs `our_function(*args)` when the argument is `my_function`
#
# ---
#
# ```python
# def f1(*args, **args):
#     pass
# ```
#
# The *arg parameter holds a list of unnamed parameters. But this code is syntactically correct despite the fact that the names of the function parameters do not follow the naming convention.
#
# ---
#
# ```python
# # Correct Line breaks and indentation
# spam = my_function(arg_1, arg_2,
#                     arg_3, arg_4)
#
# my_list = [
#     1, 2, 3,
#     4, 5, 6,
#     ]
#
# my_dict = {
#     'name': 'John',
#     'age': 30,
#     'city': 'New York',
#     'is_student': False
# }
# ```
#
# ---
#
# ```python
# # PEP 8 Recommendation for comments
#
# def area_price(area, price=2.25):
#     """Calculate the are in square meters.
#
#         Keyword Arguments:
#         area -- the land area of the slot
#         price -- price per sq/m (default 2.25)"""
#
# # Example that illustrates creating
# # a two-element list, and printing
# # the list contents to the screen.
#
# my_list = [a,b]
# print(my_list)
#
# ```
#
# ---
#
# ## Select the true statement related to PEP 257.
# B. Attribute docstrings and Additional docstrings are two types of extra docstrings that can be extracted by software tools
# - Attribute docstrings immediately follow an attribute
# - Additional Docstrings provide more detailed notes and such there are tools like Sphinx to extract documentation
#
# ---
#
# ## Select the true statements related to PEP 8 programming recommendations for code writing. (Choose two.)
# - B. You should make object type comparisons using the isinstance() method (e.g. if isinstance(obj, int):) instead of comparing types directly (e.g. if type(obj) is type(1)).
# - D. You should not write string literals that rely on significant trailing whitespaces, as they may be visually indistinguishable, and certain editors may trim them.
#
# PEP 8 actually recommends using the is not operator (e.g., if spam is not None:) for readability. The not ... is pattern is not recommended.  PEP 8 does not suggest favoring the CPython implementation over other implementations like PyPy, Cython, and Jython.
#
# ---
#
# ## Select the true statements related to PEP 8 naming conventions. (Choose two.)
# - A. Function and variable names should be lower-case with words separated by underscores.
# - B. You should always use self as the first argument to instance methods, and cls as the first argument to class methods.
#
# ---
#
# ## Select the true statement about PEP 8 recommendations related to line breaks and binary operators.
# -B. It is permissible to use line breaks before or after a binary operator, as long as the convention is consistent locally. However, for new code, it is recommended that break lines should be used only after binary operators.
#
# OR
#
# A. It is recommended that you use line breaks before binary operators to improve code readability
#
# ---
#
# ## Look at the following code snippets and decide which ones follow PEP 8 recommendations for whitespaces in expressions and statements
#
# A. No whitespace immediately before the opening parenthesis that starts the list of arguments of a function call:
# # Correct:
# f00 (5)
# # Wrong:
# £00 (5)
#
# C. No whitespace between a trailing comma and a following closing parenthesis:
# # Correct:
# spam = (1,)
# # Wrong:
# spam = (1, )
#
# ---
#
# ## Which of the following values can be returned by the messagebox.askquestion() method?
#
# "yes" and "no"
#
# ---
#
# ## What will happen if the main window is too small to fit all its widgets?
#
# Some Widgets may be invisible
#
# ---
#
# ##  What is true about the unbind() method? (Choose two.)
#
# The `unbind()` method is called on a widget's object to remove a binding for a particular event. It requires an event name as an argument to remove a specific event binding.
#
# ---
#
# ## If purple can be obtained from mixing red and blue, which color codes represent the two ingredients? (Choose two.)
# - B. #0000FF
# - C. #FF0000
#
# ---
#
# ## What is true about the invocation of the cget() method?
# - It could be used to read widget attributes
# - Replaced by a dictionary-like access manner
#
# ---
#
# ## Which of the following will set the button text’s font to 12 point italics Arial? (Choose two.)
# - button=Button(wnd, font=('Arial', '12', 'italic'))
# - button.config(font=('Arial', '12', 'italic'))
#
# ---
#
# ## What is true about the unbind_all() method? (Choose two.)
# - invoked from any widget. It is used to unbind alle vent bindings for a **particular widget**
# - parameterless. it does not take any arguments and removes all event bindings for the widget
#
# ---
#
# ## If w is a correctly created main application window, which method would you use to fix both of the main window's dimensions?
# - w.resizeable because you could set Width and Height to False which fixes the dimensions
#
# ---
#
# ## Select the true statements about the connection-oriented and connectionless types of communication. (Choose two.)
# - In the context of TCP/IP networks, the communication side that initiates a connection is called the client, whereas the side that answers the client is called the server
# - a phone call is an example of a connection-oriented communication
#
# ---
#
# ## Select the true statements about sockets. (Choose two.)
# - A. A socket is a connection point that enables a two-way communication between programs running in a network
# - D. A socket can be used to establish a communication endpoint for processes running on the same or different machines
#
# ---
#
# ## Select the true statement about the socket.gaierror exception.
# - it is raised when an address-related error caused by the getaddrinfo() and getnameinfo() function occurs
#
# ---
#
# ## True statements about the json.dumps() function
# - returns a JSON string
# - takes in Python data argument
#
# Side note for json.loads
# - returns a Python entity
# - takes JSON string as argument
#
# ---
#
# ##  What is ElementTree?
# - Built in python module that contains functions used for parsing and creating XML data
#
# ---
#
# ## The term serialization in JSON processing context is:
# - Python data turning into a JSON string
#
# ---
#
# ## Select the true statements about the following invocation: r = requests.get('http://localhost:3000') (Choose two.)
# - address a service listening at port 3000
# - service deployed at localhost
#
# ---
#
# ## A socket object is usually created by which one of the following invocations?
# - socket.socket(socket_domain, socket_type)
#
# ---
#
# ##
